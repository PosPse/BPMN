# %%
from graphviz import Digraph

# 实例化一个Digraph对象(有向图)，name:生成的图片的图片名，format:生成的图片格式
dot = Digraph(name="MyPicture1", format="png")
dot.attr('graph', rankdir='LR')
a = 'My \nPictsssssure'
dot.attr('graph', label=a)
# 添加子图，设置子图的属性
with dot.subgraph(name='cluster_a') as sub:
    sub.attr(label='Cluster A', penwidth='0', labelloc='b')  # 设置子图的标签和边界线条宽度
    sub.node('a', label='', fixedsize='true',penwidth='0', shapefile='/home/btr/bpmn/PAGED/dataset/BPMN_Icon/BpmnDataObject.png', imagescale='both', width='0.8', height='0.8')  # 添加节点a并设置标签

# 在子图外部添加节点b和c
def test(g):
    g.node('b', shape='rect', style='rounded,bold', label='Node B Node B\n Node B Node B')
# dot.node('b', shape='rect', style='rounded,bold', label='Node B Node B\n Node B Node B')
test(dot)
dot.node('c', label='Node C', penwidth='1.5')

# 添加边，连接节点a到节点b和c
dot.edge('a', 'b', label='dddd')
dot.edge('a', 'c')

# 设置图的布局方向为从左到右
# dot.graph_attr['rankdir'] = 'LR'

# 跟view一样的用法(render跟view选择一个即可)，一般用render生成图片，不使用view=True,view=True用在调试的时候
# dot.render(filename='MyPicture1', directory="/home/btr/bpmn/PAGED/dataset/image/train", cleanup=True)
dot.name
# Out:
# 'MyPicture1'

# %%
from graphviz import Digraph
from graph_utils import Graph, DrawUtil
from enum import Enum
draw_data = None
train_dataset = Graph.load_from_json('/home/btr/bpmn/PAGED/dataset/procedural_graph_extraction/dev.json')
for data in train_dataset:
    if data.agent_set == []:
        draw_data = data
        
        break
    else:
        continue

# %%
a = DrawUtil(draw_data).draw()
a

# %%
from graphviz import Digraph

# 创建一个有向图对象
dot = Digraph(name="MyPicture1", format="png")
dot.attr('graph', rankdir='LR')


with dot.subgraph(name='cluster_a') as sub:
    sub.attr(label='Start', penwidth='0', labelloc='b')
    sub.node('a', label='',fixedsize='true',penwidth='0', shapefile='/home/btr/bpmn/PAGED/dataset/BPMN_Icon/BpmnStartEvent.png', imagescale='both', width='0.8', height='0.8')

dot.node('b', shape='rect', style='rounded,bold', label='Node B Node B\n Node B Node B')

with dot.subgraph(name='cluster_c') as sub:
    sub.attr(label='', penwidth='0', labelloc='b')
    sub.node('c', label='', fixedsize='true',penwidth='0', shapefile='/home/btr/bpmn/PAGED/dataset/BPMN_Icon/BpmnGatewayOr.png', imagescale='both', width='0.8', height='0.8')

with dot.subgraph(name='cluster_d') as sub:
    sub.attr(label='', penwidth='0', labelloc='b')
    sub.node('d', label='', fixedsize='true',penwidth='0', shapefile='/home/btr/bpmn/PAGED/dataset/BPMN_Icon/BpmnGatewayXor.png', imagescale='both', width='0.8', height='0.8')

with dot.subgraph(name='cluster_e') as sub:
    sub.attr(label='', penwidth='0', labelloc='b')
    sub.node('e', label='', fixedsize='true',penwidth='0', shapefile='/home/btr/bpmn/PAGED/dataset/BPMN_Icon/BpmnGatewayParallel.png', imagescale='both', width='0.8', height='0.8')

dot.node('f', shape='rect', style='rounded,bold', label='Node B Node B\n Node B Node B')
dot.node('g', shape='rect', style='rounded,bold', label='Node B Node B\n Node B Node B')
dot.node('h', shape='rect', style='rounded,bold', label='Node B Node B\n Node B Node B')
dot.node('i', shape='rect', style='rounded,bold', label='Node B Node B\n Node B Node B')
dot.node('j', shape='rect', style='rounded,bold', label='Node B Node B\n Node B Node B')
dot.node('k', shape='rect', style='rounded,bold', label='Node B Node B\n Node B Node B')

with dot.subgraph(name='cluster_l') as sub:
    sub.attr(label='data', penwidth='0', labelloc='b')
    sub.node('l', label='', fixedsize='true',penwidth='0', shapefile='/home/btr/bpmn/PAGED/dataset/BPMN_Icon/BpmnDataObject.png', imagescale='both', width='0.8', height='0.8')

with dot.subgraph(name='cluster_m') as sub:
    sub.attr(label='annotation', penwidth='0', labelloc='b')
    sub.node('m', label='', fixedsize='true',penwidth='0', shapefile='/home/btr/bpmn/PAGED/dataset/BPMN_Icon/BpmnTextAnnotation.png', imagescale='both', width='0.8', height='0.8')

with dot.subgraph(name='cluster_n') as sub:
    sub.attr(label='End', penwidth='0', labelloc='b')
    sub.node('n', label='', fixedsize='true',penwidth='0', shapefile='/home/btr/bpmn/PAGED/dataset/BPMN_Icon/BpmnEndEvent.png', imagescale='both', width='0.8', height='0.8')

dot.edge('a', 'b')
dot.edge('b', 'c')
dot.edge('b', 'd')
dot.edge('b', 'e')
dot.edge('c', 'f')
dot.edge('c', 'g')
dot.edge('d', 'h')
dot.edge('d', 'i')
dot.edge('e', 'j')
dot.edge('e', 'k')
dot.edge('f', 'n')
dot.edge('g', 'n')
dot.edge('h', 'n')
dot.edge('i', 'n')
dot.edge('j', 'n')
dot.edge('k', 'n')
dot.edge('l', 'g')
dot.edge('m', 'j')
dot
# dot.render(filename='MyPicture1', directory="/home/btr/bpmn/PAGED/dataset/image/train", cleanup=True)

# %%
from graphviz import Digraph

g = Digraph('G', filename='cluster.gv')
# g.attr('graph', rankdir='LR')
# NOTE: the subgraph name needs to begin with 'cluster' (all lowercase)
#       so that Graphviz recognizes it as a special cluster subgraph

with g.subgraph(name='cluster_0') as c:
    c.attr(style='filled', color='lightgrey')
    c.node_attr.update(style='filled', color='white')
    c.edges([('a0', 'a1')])
    c.attr(label='process #1')

with g.subgraph(name='cluster_1') as c:
    c.attr(color='blue')
    c.node_attr['style'] = 'filled'
    c.edges([('b0', 'b2'), ('b2', 'b3')])
    c.attr(label='process #2')

with g.subgraph(name='cluster_0') as c:
    c.attr(style='filled', color='lightgrey')
    c.node_attr.update(style='filled', color='white')
    c.edges([('a1', 'a2'), ('a2', 'a3')])
    c.attr(label='process #1')

g.edge('start', 'a0')
g.edge('start', 'b0')
g.edge('a1', 'b3')
g.edge('b2', 'a3')
g.edge('a3', 'a0')
g.edge('a3', 'end')
g.edge('b3', 'end')

g.node('start', shape='Mdiamond')
g.node('end', shape='Msquare')
g

# %%
from graph_utils import DrawUtil, 
a = DrawUtil('a')
d = a.test()
d

# %%
from graphviz import Digraph

dot = Digraph(comment='The Round Table')
dot.node('a')

def test(g):
    with g.subgraph(name='cluster_1') as sub:
        sub.attr(label='process #1')
        sub.node('c', label='Node C')

with dot.subgraph(name='cluster_0') as sub:
    sub.attr(label='process #0')
    sub.node('b', label='Node A')
    test(sub)

dot

# %%
import os
from tqdm import tqdm
import shutil

path1 = '/home/btr/bpmn/PAGED/dataset/bpmai/models'
path2 = '/home/btr/bpmn/PAGED/dataset/image/test'

file_list = os.listdir(path1)
file_list = [file for file in file_list if file.endswith('.svg')]

file_list_2 = os.listdir(path2)
file_list_3 = list(map(lambda x: x.split('.')[0], file_list_2))
file_list_3 = sorted(file_list_3, key=lambda x: int(x))
for file in tqdm(file_list_3):
    # print(file)
    svg_path = path1 + '/' + file + '.meta.json'
    png_path = path2 + '/' + file + '.meta.json'
    # print(svg_path, png_path)
    shutil.copy(svg_path, png_path)
    # break
# Out:
# 100%|██████████| 3462/3462 [00:00<00:00, 23134.04it/s]
